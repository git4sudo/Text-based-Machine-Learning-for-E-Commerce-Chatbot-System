# %% [markdown]
# <a href="https://colab.research.google.com/github/git4sudo/Text-based-Machine-Learning-for-E-Commerce-Chatbot-System/blob/main/KeyBert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls drive/MyDrive/CS541/data
# Out:
# FashionDataset.csv  wikipedia-list-of-colors.txt

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1) Preprocessing

# %% [markdown]
# ## 1.1) Load Dataset

# %%
df = pd.read_csv("drive/MyDrive/CS541/data/FashionDataset.csv")

df = df[df.columns[1:]]
df = df.rename(columns={"Deatils": "Details"})
pd.options.display.max_colwidth = 100

# %%
df
# Out:
#          BrandName  \
# 0             life
# 1             only
# 2          fratini
# 3      zink london
# 4             life
# ...            ...
# 30753    swarovski
# 30754          Nan
# 30755       jewelz
# 30756      estelle
# 30757      estelle
#
#                                                                   Details  \
# 0             solid cotton blend collar neck womens a-line dress - indigo
# 1                polyester peter pan collar womens blouson dress - yellow
# 2          solid polyester blend wide neck womens regular top - off white
# 3                  stripes polyester sweetheart neck womens dress - black
# 4                   regular fit regular length denim womens jeans - stone
# ...                                                                   ...
# 30753                             crystal stylish womens rodhium earrings
# 30754                                                                 Nan
# 30755                                  ethnic gold plated jhumki earrings
# 30756  womens gold plated double line fancy white and gold pearl necklace
# 30757            womens gold plated bridge designer mangalsutra necklaces
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 30753                                      Nan       Nan      8950      Nan
# 30754                                      Nan       Nan       Nan      Nan
# 30755                                      Nan  Rs\n1839       643  65% off
# 30756                                      Nan       Nan      2799      Nan
# 30757                                      Nan       Nan      1899      Nan
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30753    Jewellery-Women
# 30754    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [30758 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  30758 non-null  object
#  1   Details    30758 non-null  object
#  2   Sizes      30758 non-null  object
#  3   MRP        30758 non-null  object
#  4   SellPrice  30758 non-null  object
#  5   Discount   30758 non-null  object
#  6   Category   30758 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# ## 1.2) Find and Update Nulls

# %%
#"Nan" string is used instead of null-value so replace to find true nulls

df = df.replace("Nan", np.NaN)

df
# Out:
#          BrandName  \
# 0             life
# 1             only
# 2          fratini
# 3      zink london
# 4             life
# ...            ...
# 30753    swarovski
# 30754          NaN
# 30755       jewelz
# 30756      estelle
# 30757      estelle
#
#                                                                   Details  \
# 0             solid cotton blend collar neck womens a-line dress - indigo
# 1                polyester peter pan collar womens blouson dress - yellow
# 2          solid polyester blend wide neck womens regular top - off white
# 3                  stripes polyester sweetheart neck womens dress - black
# 4                   regular fit regular length denim womens jeans - stone
# ...                                                                   ...
# 30753                             crystal stylish womens rodhium earrings
# 30754                                                                 NaN
# 30755                                  ethnic gold plated jhumki earrings
# 30756  womens gold plated double line fancy white and gold pearl necklace
# 30757            womens gold plated bridge designer mangalsutra necklaces
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 30753                                      NaN       NaN      8950      NaN
# 30754                                      NaN       NaN       NaN      NaN
# 30755                                      NaN  Rs\n1839       643  65% off
# 30756                                      NaN       NaN      2799      NaN
# 30757                                      NaN       NaN      1899      NaN
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30753    Jewellery-Women
# 30754    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [30758 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  29575 non-null  object
#  1   Details    29575 non-null  object
#  2   Sizes      23257 non-null  object
#  3   MRP        22550 non-null  object
#  4   SellPrice  29575 non-null  object
#  5   Discount   22550 non-null  object
#  6   Category   30758 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %%
plt.hist(df.isnull().sum(axis=1))
plt.title("Found nulls in each row")
plt.show()

# %%
df = df[df.isnull().sum(axis=1) != 6]

# %%
#Sizes, MRP and Discount still contain nulls
#MRP and Discount have same non-null count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29575 entries, 0 to 30757
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  29575 non-null  object
#  1   Details    29575 non-null  object
#  2   Sizes      23257 non-null  object
#  3   MRP        22550 non-null  object
#  4   SellPrice  29575 non-null  object
#  5   Discount   22550 non-null  object
#  6   Category   29575 non-null  object
# dtypes: object(7)
# memory usage: 1.8+ MB

# %%
#Check if MRP and Discount are actually both non nulls in respective rows
np.all(df["MRP"].isnull() == df["Discount"].isnull())
# Out:
# True

# %%
#Examples: MRP is maximum retail, thus it is equal to sellprice (cost with discount) since there is no discount.
df[df["MRP"].isnull()].head()
# Out:
#    BrandName  \
# 28    zink z
# 36   fratini
# 61     levis
# 69     levis
# 92   fratini
#
#                                                                            Details  \
# 28                                   solid cotton blend v neck womens top - maroon
# 36                  printed polyester blend round neck womens a-line dress - white
# 61                                graphic cotton round neck womens t-shirt - brown
# 69                      tapered fit regular length cotton womens jeans - dk indigo
# 92  sanya malhotra regular fit regular length cotton linen womens culottes - olive
#
#                                        Sizes  MRP SellPrice Discount  \
# 28   Size:Large,Medium,Small,X-Large,X-Small  NaN      1299      NaN
# 36  Size:Large,Medium,Small,X-Large,XX-Large  NaN      1799      NaN
# 61           Size:Large,Medium,Small,X-Small  NaN      1199      NaN
# 69                       Size:26,28,30,32,34  NaN      3799      NaN
# 92                    Size:26,28,30,32,34,36  NaN      1299      NaN
#
#              Category
# 28  Westernwear-Women
# 36  Westernwear-Women
# 61  Westernwear-Women
# 69  Westernwear-Women
# 92  Westernwear-Women

# %%
#Drop MRP and use sell price for cost, replace nulls in Discount with "No" discount
df = df.drop(["MRP"], axis=1)

# %%
df["Discount"][df["Discount"].isnull()] = "No"

# %%
df
# Out:
#                 BrandName  \
# 0                    life
# 1                    only
# 2                 fratini
# 3             zink london
# 4                    life
# ...                   ...
# 30752  shaya by caratlane
# 30753           swarovski
# 30755              jewelz
# 30756             estelle
# 30757             estelle
#
#                                                                   Details  \
# 0             solid cotton blend collar neck womens a-line dress - indigo
# 1                polyester peter pan collar womens blouson dress - yellow
# 2          solid polyester blend wide neck womens regular top - off white
# 3                  stripes polyester sweetheart neck womens dress - black
# 4                   regular fit regular length denim womens jeans - stone
# ...                                                                   ...
# 30752                                the wing woman clover charm necklace
# 30753                             crystal stylish womens rodhium earrings
# 30755                                  ethnic gold plated jhumki earrings
# 30756  womens gold plated double line fancy white and gold pearl necklace
# 30757            womens gold plated bridge designer mangalsutra necklaces
#
#                                          Sizes SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small       849  50% off
# 1                             Size:34,36,38,40      2449  30% off
# 2                  Size:Large,X-Large,XX-Large       599  50% off
# 3              Size:Large,Medium,Small,X-Large      1379  40% off
# 4                       Size:26,28,30,32,34,36       849  50% off
# ...                                        ...       ...      ...
# 30752                                      NaN      1250       No
# 30753                                      NaN      8950       No
# 30755                                      NaN       643  65% off
# 30756                                      NaN      2799       No
# 30757                                      NaN      1899       No
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30752    Jewellery-Women
# 30753    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [29575 rows x 6 columns]

# %%
#only nulls in sizes now
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29575 entries, 0 to 30757
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  29575 non-null  object
#  1   Details    29575 non-null  object
#  2   Sizes      23257 non-null  object
#  3   SellPrice  29575 non-null  object
#  4   Discount   29575 non-null  object
#  5   Category   29575 non-null  object
# dtypes: object(6)
# memory usage: 1.6+ MB

# %% [markdown]
# ## 1.3) Preprocessing

# %% [markdown]
# ## 1.3.1) Prices

# %%
#Convert sell price to numeric

df["SellPrice"] = df["SellPrice"].astype(float)

# %%
#possibly bad data check for outliers
sns.histplot(df["SellPrice"])
plt.title("Prices histogram")
plt.show()

# %%
#prices under 30K
sns.histplot(df["SellPrice"][df["SellPrice"] < 30000])
plt.title("Prices less than 30,000 histogram")
plt.show()

# %%
print("Lowest Cost Products: ")
df.sort_values(by=["SellPrice"]).head(10)
# Out:
# Lowest Cost Products:
#       BrandName  \
# 2155       life
# 29174    ayesha
# 29366    ayesha
# 29154    ayesha
# 29263    ayesha
# 29041    ayesha
# 29503    ayesha
# 30127    ayesha
# 29652    ayesha
# 29276    ayesha
#
#                                                                       Details  \
# 2155                    womens 2 ply protective face mask - pack of 5 - multi
# 29174                                     womens gold plated earrings - multi
# 29366                                   womens silver plated earrings - multi
# 29154                                                   womens multi earrings
# 29263                                     womens gold plated earrings - multi
# 29041                                     womens gold plated earrings - multi
# 29503                  womens geometric metallic studs set of 6 pairs - multi
# 30127                                   womens silver plated earrings - multi
# 29652         womens hearts and flowers metallic studs set of 6 pairs - multi
# 29276  mens rugged brown leather adjustable multi-layer bracelet and necklace
#
#       Sizes  SellPrice Discount           Category
# 2155    NaN       74.0  50% off  Westernwear-Women
# 29174   NaN       89.0  70% off    Jewellery-Women
# 29366   NaN       89.0  70% off    Jewellery-Women
# 29154   NaN       89.0  70% off    Jewellery-Women
# 29263   NaN       89.0  70% off    Jewellery-Women
# 29041   NaN       89.0  70% off    Jewellery-Women
# 29503   NaN       89.0  70% off    Jewellery-Women
# 30127   NaN       89.0  70% off    Jewellery-Women
# 29652   NaN       89.0  70% off    Jewellery-Women
# 29276   NaN       89.0  70% off    Jewellery-Women

# %%
print("Highest Cost Products: ")
df.sort_values(by=["SellPrice"]).tail(10)
# Out:
# Highest Cost Products:
#       BrandName  \
# 27297   versace
# 27431    tissot
# 27844   versace
# 27437   versace
# 28168   versace
# 27704   versace
# 27927   versace
# 28322   versace
# 27551   versace
# 27539   versace
#
#                                                                                              Details  \
# 27297                 womens blue dial pop chic lady 36mm stainless steel analogue watch - vevd00319
# 27431  mens 39.3 mm le locle powermatic 80 blue dial stainless steel analogue watch - t0064071104300
# 27844                                   womens white pop chic lady 36mm analogue watch - wvevd00519n
# 27437                                     womens 36 mm blue dial bracelet analogue watch - vek400821
# 28168                                womens v- motif gold-tone yellow gold ion plated analogue watch
# 27704                womens 35 mm v-motif white-silver dial stainless steel analog watch - vere02420
# 27927           womens 36 mm versace essential black dial stainless steel analogue watch - vek400621
# 28322                                     unisex 43 mm pink dial bracelet analogue watch - vez300621
# 27551                womens 34 mm meander white dial steel ion plating 5n analogue watch - velw00620
# 27539    womens 36 mm greca icon silver white guilloch dial stainless steel analog watch - vez600621
#
#       Sizes  SellPrice Discount       Category
# 27297   NaN    44000.0       No  Watches-Women
# 27431   NaN    48500.0       No  Watches-Women
# 27844   NaN    48500.0       No  Watches-Women
# 27437   NaN    55700.0       No  Watches-Women
# 28168   NaN    91100.0       No  Watches-Women
# 27704   NaN    91900.0       No  Watches-Women
# 27927   NaN    99100.0       No  Watches-Women
# 28322   NaN   108000.0       No  Watches-Women
# 27551   NaN   137900.0       No  Watches-Women
# 27539   NaN   142500.0       No  Watches-Women

# %% [markdown]
# Based on the highest/lowest items, it is likely these are the correct values, since products like face masks, and cheap earrings cost less (\$1), while name brands i.e versace costs 50,000-100,000Rs (\$1000) range.

# %% [markdown]
# ## 1.3.2) Sizes

# %%
#check error size, possibly not only for watches/perfumes
df[df["Sizes"].isnull() != True]
# Out:
#             BrandName  \
# 0                life
# 1                only
# 2             fratini
# 3         zink london
# 4                life
# ...               ...
# 26885     swiss eagle
# 27290  lawman watches
# 28418  lawman watches
# 28664         miu miu
# 28716         miu miu
#
#                                                               Details  \
# 0         solid cotton blend collar neck womens a-line dress - indigo
# 1            polyester peter pan collar womens blouson dress - yellow
# 2      solid polyester blend wide neck womens regular top - off white
# 3              stripes polyester sweetheart neck womens dress - black
# 4               regular fit regular length denim womens jeans - stone
# ...                                                               ...
# 26885                                  womens analogue metallic watch
# 27290   womens rose gold dial stainless steel analogue watch - wi106d
# 28418    womens silver dial stainless steel analogue watch - lwwi105a
# 28664                                           eau de parfum - 50 ml
# 28716                                           eau de parfum - 30 ml
#
#                                          Sizes  SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small      849.0  50% off
# 1                             Size:34,36,38,40     2449.0  30% off
# 2                  Size:Large,X-Large,XX-Large      599.0  50% off
# 3              Size:Large,Medium,Small,X-Large     1379.0  40% off
# 4                       Size:26,28,30,32,34,36      849.0  50% off
# ...                                        ...        ...      ...
# 26885                          Size:Error Size     4197.0  70% off
# 27290                          Size:Error Size     4999.0  33% off
# 28418                          Size:Error Size     3999.0  33% off
# 28664                          Size:Error Size     6100.0       No
# 28716                          Size:Error Size     4400.0       No
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
# 28664    Fragrance-Women
# 28716    Fragrance-Women
#
# [23257 rows x 6 columns]

# %%
#these contain clothes as well so convert to null
df[df["Sizes"] == "Size:Error Size"].head(10)
# Out:
#      BrandName                                                      Details  \
# 6807    jockey                          women cotton v-neck t-shirt - black
# 7784    jockey                cotton elastane womens t-shirt - blue melange
# 7878    jockey                                 womens v neck t-shirt - wine
# 8112    jockey                         womens round neck slub t-shirt - red
# 8509    jockey           tactel nylon womens activewear track pants - black
# 8744    jockey                            womens v neck t-shirt - sea green
# 8803    jockey  polyester spandex womens activewear track pants - weft_blue
# 9060    jockey                cotton elastane womens t-shirt - blue melange
# 9105    jockey                        womens round neck slub t-shirt - pink
# 9349    jockey                           womens v neck solid t-shirt - blue
#
#                 Sizes  SellPrice Discount           Category
# 6807  Size:Error Size      399.0       No  Westernwear-Women
# 7784  Size:Error Size      499.0       No  Westernwear-Women
# 7878  Size:Error Size      649.0       No  Westernwear-Women
# 8112  Size:Error Size      439.0       No  Westernwear-Women
# 8509  Size:Error Size     1799.0       No  Westernwear-Women
# 8744  Size:Error Size      649.0       No  Westernwear-Women
# 8803  Size:Error Size     1129.0       No  Westernwear-Women
# 9060  Size:Error Size      549.0       No  Westernwear-Women
# 9105  Size:Error Size      439.0       No  Westernwear-Women
# 9349  Size:Error Size      399.0       No  Westernwear-Women

# %%
df["Sizes"] = df["Sizes"].replace("Size:Error Size", np.NaN)

# %%
#update indexes after dropping values
df = df.reset_index(drop=True)

# %%
#get smallest and largest size in numeric US standard (0 XXS -> 26 4X)
def getSizes(size):

  #replace null with unweighted value
  if not isinstance(size, str):
    return ["None", "None"]


  size = size.replace("Size:", "")
  size = size.split(",")

  return [size[0], size[-1]]

#conversion from weight (inches) -> usa, via best fit line
# usa = 1.1144(inches) - 26.719

weight_to_usa = lambda x: round(1.1144*x - 26.719)

def convertSize(sizeval):

  #nulls
  if sizeval == "None":
    return -1

  #numeric
  if sizeval.isdigit():
    converted = weight_to_usa(int(sizeval))
    #if a conversion goes to negative it is likely already in usa standard
    if converted < 0:
      return int(sizeval)
    return converted

  #strings

  #count number of x's to handle x-large, x-small etc
  count_xs = sizeval.count("X")

  #small
  if "S" in sizeval:
    if count_xs >= 2:
      return 0
    elif count_xs == 1:
      return 1
    else:
      return 3

  #medium
  if "M" in sizeval:
    return 7

  #large
  if "L" in sizeval:
    if count_xs >= 2:
      return 15
    elif count_xs == 1:
      return 11
    else:
      return 9

  return -1

def convertSizeList(sizes):
  convert = getSizes(sizes)
  return sorted([convertSize(size) for size in convert])

# %%
df[["MinSize", "MaxSize"]] = df["Sizes"].apply(convertSizeList).to_list()

# %%
df
# Out:
#                 BrandName  \
# 0                    life
# 1                    only
# 2                 fratini
# 3             zink london
# 4                    life
# ...                   ...
# 29570  shaya by caratlane
# 29571           swarovski
# 29572              jewelz
# 29573             estelle
# 29574             estelle
#
#                                                                   Details  \
# 0             solid cotton blend collar neck womens a-line dress - indigo
# 1                polyester peter pan collar womens blouson dress - yellow
# 2          solid polyester blend wide neck womens regular top - off white
# 3                  stripes polyester sweetheart neck womens dress - black
# 4                   regular fit regular length denim womens jeans - stone
# ...                                                                   ...
# 29570                                the wing woman clover charm necklace
# 29571                             crystal stylish womens rodhium earrings
# 29572                                  ethnic gold plated jhumki earrings
# 29573  womens gold plated double line fancy white and gold pearl necklace
# 29574            womens gold plated bridge designer mangalsutra necklaces
#
#                                          Sizes  SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small      849.0  50% off
# 1                             Size:34,36,38,40     2449.0  30% off
# 2                  Size:Large,X-Large,XX-Large      599.0  50% off
# 3              Size:Large,Medium,Small,X-Large     1379.0  40% off
# 4                       Size:26,28,30,32,34,36      849.0  50% off
# ...                                        ...        ...      ...
# 29570                                      NaN     1250.0       No
# 29571                                      NaN     8950.0       No
# 29572                                      NaN      643.0  65% off
# 29573                                      NaN     2799.0       No
# 29574                                      NaN     1899.0       No
#
#                 Category  MinSize  MaxSize
# 0      Westernwear-Women        1        9
# 1      Westernwear-Women       11       18
# 2      Westernwear-Women        9       15
# 3      Westernwear-Women        9       11
# 4      Westernwear-Women        2       13
# ...                  ...      ...      ...
# 29570    Jewellery-Women       -1       -1
# 29571    Jewellery-Women       -1       -1
# 29572    Jewellery-Women       -1       -1
# 29573    Jewellery-Women       -1       -1
# 29574    Jewellery-Women       -1       -1
#
# [29575 rows x 8 columns]

# %% [markdown]
# Two new features, min and max sizes that follow U.S conversion. Assumption is that there are clothes for any size between the two ranges. Also that any sizes that are negative either do not have a size, or are not clothing (fragrance, jewellery etc).

# %% [markdown]
# ## 1.3.3) Category

# %%
#check if categories should be spread
df["Category"].unique()
# Out:
# array(['Westernwear-Women', 'Indianwear-Women',
#        'Lingerie&Nightwear-Women', 'Footwear-Women', 'Watches-Women',
#        'Fragrance-Women', 'Jewellery-Women'], dtype=object)

# %%
sns.histplot(df["Category"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Categories all are labeled under "Women" so it is safe to keep, in the case of men/fluid clothes might be preferrable to separate into labels for each type of clothing/item

# %% [markdown]
# ## 1.3.4) Discount

# %%
#add boolean feature for check if item is discounted
df["isDiscounted"] = df["Discount"] != "No"

# %%
df
# Out:
#                 BrandName  \
# 0                    life
# 1                    only
# 2                 fratini
# 3             zink london
# 4                    life
# ...                   ...
# 29570  shaya by caratlane
# 29571           swarovski
# 29572              jewelz
# 29573             estelle
# 29574             estelle
#
#                                                                   Details  \
# 0             solid cotton blend collar neck womens a-line dress - indigo
# 1                polyester peter pan collar womens blouson dress - yellow
# 2          solid polyester blend wide neck womens regular top - off white
# 3                  stripes polyester sweetheart neck womens dress - black
# 4                   regular fit regular length denim womens jeans - stone
# ...                                                                   ...
# 29570                                the wing woman clover charm necklace
# 29571                             crystal stylish womens rodhium earrings
# 29572                                  ethnic gold plated jhumki earrings
# 29573  womens gold plated double line fancy white and gold pearl necklace
# 29574            womens gold plated bridge designer mangalsutra necklaces
#
#                                          Sizes  SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small      849.0  50% off
# 1                             Size:34,36,38,40     2449.0  30% off
# 2                  Size:Large,X-Large,XX-Large      599.0  50% off
# 3              Size:Large,Medium,Small,X-Large     1379.0  40% off
# 4                       Size:26,28,30,32,34,36      849.0  50% off
# ...                                        ...        ...      ...
# 29570                                      NaN     1250.0       No
# 29571                                      NaN     8950.0       No
# 29572                                      NaN      643.0  65% off
# 29573                                      NaN     2799.0       No
# 29574                                      NaN     1899.0       No
#
#                 Category  MinSize  MaxSize  isDiscounted
# 0      Westernwear-Women        1        9          True
# 1      Westernwear-Women       11       18          True
# 2      Westernwear-Women        9       15          True
# 3      Westernwear-Women        9       11          True
# 4      Westernwear-Women        2       13          True
# ...                  ...      ...      ...           ...
# 29570    Jewellery-Women       -1       -1         False
# 29571    Jewellery-Women       -1       -1         False
# 29572    Jewellery-Women       -1       -1          True
# 29573    Jewellery-Women       -1       -1         False
# 29574    Jewellery-Women       -1       -1         False
#
# [29575 rows x 9 columns]

# %% [markdown]
# # 2) Tokenization + Data Augmentation

# %%
details_dataset = df["Details"]

# %%
print("First 20 Values")
details_dataset.to_frame().head(20)
# Out:
# First 20 Values
#                                                            Details
# 0      solid cotton blend collar neck womens a-line dress - indigo
# 1         polyester peter pan collar womens blouson dress - yellow
# 2   solid polyester blend wide neck womens regular top - off white
# 3           stripes polyester sweetheart neck womens dress - black
# 4            regular fit regular length denim womens jeans - stone
# 5               wide ankle length cotton womens jeans - light blue
# 6       printed cotton blend collared womens regular dress - white
# 7       embroidered wide neck polyester womens regular top - blush
# 8               floral polyester v neck womens flared dress - navy
# 9               checks cotton boat neck womens regular top - black
# 10            solid square neck cotton womens regular dress - pink
# 11          regular fit regular length denim womens jeans - indigo
# 12          printed blended round neck womens shift dress - orange
# 13                printed jersey round neck womens t-shirt - black
# 14                     printed crepe square neck womens top - blue
# 15                    solid cotton collar neck womens shirt - pink
# 16            solid cotton lycra round neck womens t-shirt - white
# 17                 printed cotton collar neck womens shirt - white
# 18                solid cotton v neck womens formal shirt - maroon
# 19       regular fit regular length denim womens jeans - mid stone

# %%
print("Last 20 Values")
details_dataset.to_frame().tail(20)
# Out:
# Last 20 Values
#                                                                                                    Details
# 29555                                                                   elan dual ring rose gold - size 60
# 29556                                         combo pack set of 9 gold earrings and set of 3 gold hairpins
# 29557                            925 silver real pearl aki pendant with chain necklace rhodium plated gift
# 29558                         womens metallic silver double drop with black stone western earrings - multi
# 29559                            womens 925 sterling silver poppy mangalsutra tanmaniya pendant with chain
# 29560                                                      vintage motifs multicolor bracelet - jf02854998
# 29561                                                cubic zirconia silver push back clasp womens earrings
# 29562                                                               womens jad/pearl golden chain - yellow
# 29563                                          womens candy bracelet with white american diamonds bracelet
# 29564                                                       beautiful white crystal silver plated earrings
# 29565  womens metallic gold statement multilayered chain with bar and ring lock detail western necklace...
# 29566                                           nine pieces combo fashion non-precious metal base earrings
# 29567                                                                            womens pearl golden drops
# 29568                                                             sterling silver oval turquoise ear studs
# 29569                                                     constella stylish crystal white pierced earrings
# 29570                                                                 the wing woman clover charm necklace
# 29571                                                              crystal stylish womens rodhium earrings
# 29572                                                                   ethnic gold plated jhumki earrings
# 29573                                   womens gold plated double line fancy white and gold pearl necklace
# 29574                                             womens gold plated bridge designer mangalsutra necklaces

# %%
import re

# %%
def clean_details(detail):
  '''
  drop color seperator
  space slashes
  drop numbers
  drop empty values
  drop values with 1 char
  drop stop words
  lowercase
  '''

  output = detail.replace(" - ", " ")
  # / = chr(47)
  output = output.replace(chr(47), " ")
  output = re.sub(r'\d+', '', output)
  output = output.split(" ")
  output = [word for word in output if word != ""]
  text = [word.lower() for word in output if len(word) > 1]

  stop_words = ["ourselves", "hers", "between", "yourself", "but", "again", "there", "about", "once", "during", "out", "very", "having", "with", "they", "own", "an", "be", "some", "for", "do", "its", "yours", "such", "into", "of", "most", "itself", "other", "off", "is", "s", "am", "or", "who", "as", "from", "him", "each", "the", "themselves", "until", "below", "are", "we", "these", "your", "his", "through", "don", "nor", "me", "were", "her", "more", "himself", "this", "down", "should", "our", "their", "while", "above", "both", "up", "to", "ours", "had", "she", "all", "no", "when", "at", "any", "before", "them", "same", "and", "been", "have", "in", "will", "on", "does", "yourselves", "then", "that", "because", "what", "over", "why", "so", "can", "did", "not", "now", "under", "he", "you", "herself", "has", "just", "where", "too", "only", "myself", "which", "those", "i", "after", "few", "whom", "t", "being", "if", "theirs", "my", "against", "a", "by", "doing", "it", "how", "further", "was", "here", "than"]
  output = [word for word in output if word not in stop_words]
  output = [word.lower() for word in output]


  return output

# %%
for i in range(0, 25):
  print(f"\nSample #{i+1}:")
  print(clean_details(details_dataset[i]))

for i in range(29550, 29573):
  print(f"\nSample #{i+1}:")
  print(clean_details(details_dataset[i]))
# Out:
# Sample #1:
# ['solid', 'cotton', 'blend', 'collar', 'neck', 'womens', 'a-line', 'dress', 'indigo']
#
# Sample #2:
# ['polyester', 'peter', 'pan', 'collar', 'womens', 'blouson', 'dress', 'yellow']
#
# Sample #3:
# ['solid', 'polyester', 'blend', 'wide', 'neck', 'womens', 'regular', 'top', 'white']
#
# Sample #4:
# ['stripes', 'polyester', 'sweetheart', 'neck', 'womens', 'dress', 'black']
#
# Sample #5:
# ['regular', 'fit', 'regular', 'length', 'denim', 'womens', 'jeans', 'stone']
#
# Sample #6:
# ['wide', 'ankle', 'length', 'cotton', 'womens', 'jeans', 'light', 'blue']
#
# Sample #7:
# ['printed', 'cotton', 'blend', 'collared', 'womens', 'regular', 'dress', 'white']
#
# Sample #8:
# ['embroidered', 'wide', 'neck', 'polyester', 'womens', 'regular', 'top', 'blush']
#
# Sample #9:
# ['floral', 'polyester', 'v', 'neck', 'womens', 'flared', 'dress', 'navy']
#
# Sample #10:
# ['checks', 'cotton', 'boat', 'neck', 'womens', 'regular', 'top', 'black']
#
# Sample #11:
# ['solid', 'square', 'neck', 'cotton', 'womens', 'regular', 'dress', 'pink']
#
# Sample #12:
# ['regular', 'fit', 'regular', 'length', 'denim', 'womens', 'jeans', 'indigo']
#
# Sample #13:
# ['printed', 'blended', 'round', 'neck', 'womens', 'shift', 'dress', 'orange']
#
# Sample #14:
# ['printed', 'jersey', 'round', 'neck', 'womens', 't-shirt', 'black']
#
# Sample #15:
# ['printed', 'crepe', 'square', 'neck', 'womens', 'top', 'blue']
#
# Sample #16:
# ['solid', 'cotton', 'collar', 'neck', 'womens', 'shirt', 'pink']
#
# Sample #17:
# ['solid', 'cotton', 'lycra', 'round', 'neck', 'womens', 't-shirt', 'white']
#
# Sample #18:
# ['printed', 'cotton', 'collar', 'neck', 'womens', 'shirt', 'white']
#
# Sample #19:
# ['solid', 'cotton', 'v', 'neck', 'womens', 'formal', 'shirt', 'maroon']
#
# Sample #20:
# ['regular', 'fit', 'regular', 'length', 'denim', 'womens', 'jeans', 'mid', 'stone']
#
# Sample #21:
# ['solid', 'round', 'neck', 'viscose', 'womens', 'regular', 'dress', 'olive']
#
# Sample #22:
# ['solid', 'wide', 'neck', 'viscose', 'womens', 'regular', 'top', 'blue']
#
# Sample #23:
# ['printed', 'regular', 'neck', 'cotton', 'womens', 'formal', 'shirt', 'ecru']
#
# Sample #24:
# ['regular', 'fit', 'regular', 'length', 'denim', 'womens', 'jeans', 'mid', 'stone']
#
# Sample #25:
# ['floral', 'viscose', 'sweetheart', 'neck', 'womens', 'dress', 'green']
#
# Sample #29551:
# ['sterling', 'silver', 'gold', 'plated', 'citrine', 'ascending', 'earrings']
#
# Sample #29552:
# ['crystal', 'stylish', 'womens', 'blue', 'necklace']
#
# Sample #29553:
# ['womens', 'infinity', 'rose', 'gold', 'bracelet', 'using', 'swarovski', 'stones']
#
# Sample #29554:
# ['cotton', 'multicolour', 'girls', 'hair', 'bands']
#
# Sample #29555:
# ['womens', 'modern', 'shapes', 'stone', 'statement', 'necklace', 'multi']
#
# Sample #29556:
# ['elan', 'dual', 'ring', 'rose', 'gold', 'size']
#
# Sample #29557:
# ['combo', 'pack', 'set', 'gold', 'earrings', 'set', 'gold', 'hairpins']
#
# Sample #29558:
# ['silver', 'real', 'pearl', 'aki', 'pendant', 'chain', 'necklace', 'rhodium', 'plated', 'gift']
#
# Sample #29559:
# ['womens', 'metallic', 'silver', 'double', 'drop', 'black', 'stone', 'western', 'earrings', 'multi']
#
# Sample #29560:
# ['womens', 'sterling', 'silver', 'poppy', 'mangalsutra', 'tanmaniya', 'pendant', 'chain']
#
# Sample #29561:
# ['vintage', 'motifs', 'multicolor', 'bracelet', 'jf']
#
# Sample #29562:
# ['cubic', 'zirconia', 'silver', 'push', 'back', 'clasp', 'womens', 'earrings']
#
# Sample #29563:
# ['womens', 'jad', 'pearl', 'golden', 'chain', 'yellow']
#
# Sample #29564:
# ['womens', 'candy', 'bracelet', 'white', 'american', 'diamonds', 'bracelet']
#
# Sample #29565:
# ['beautiful', 'white', 'crystal', 'silver', 'plated', 'earrings']
#
# Sample #29566:
# ['womens', 'metallic', 'gold', 'statement', 'multilayered', 'chain', 'bar', 'ring', 'lock', 'detail', 'western', 'necklace', 'multi']
#
# Sample #29567:
# ['nine', 'pieces', 'combo', 'fashion', 'non-precious', 'metal', 'base', 'earrings']
#
# Sample #29568:
# ['womens', 'pearl', 'golden', 'drops']
#
# Sample #29569:
# ['sterling', 'silver', 'oval', 'turquoise', 'ear', 'studs']
#
# Sample #29570:
# ['constella', 'stylish', 'crystal', 'white', 'pierced', 'earrings']
#
# Sample #29571:
# ['wing', 'woman', 'clover', 'charm', 'necklace']
#
# Sample #29572:
# ['crystal', 'stylish', 'womens', 'rodhium', 'earrings']
#
# Sample #29573:
# ['ethnic', 'gold', 'plated', 'jhumki', 'earrings']

# %%
ecommerce_details = [clean_details(detail) for detail in details_dataset]

# %%
word_dict = {}
seen_words = []
for doc in ecommerce_details:
    for word in doc:
        if word not in word_dict:
            word_dict[word] = 1
        else:
            word_dict[word] += 1

# %%
count_words = sorted(word_dict.items(), key=lambda x: x[1])
k_words = 25
top_words = list(reversed(count_words))[:k_words]

# %%
plt.figure(figsize=(18,5))
plt.bar([k for (k,v) in top_words], [v for (k,v) in top_words])
plt.title(f"Top-{k_words} words in whole ecommerce collection")
plt.show()

# %% [markdown]
# Some key-words to abstract for modelling include:
#
#
# 1.   Colors: black, pink, white ...
# 2.   Textures: cotton, polyester, zari
# 3.   Styles: casual, festive
# 4.   Type: neck, wear, dress

# %% [markdown]
# ## 3.1) Colors
#
# Extract color features by check if string is in big list of colors from wikipedia

# %%
wiki_colors = [color.lower() for color in open("drive/MyDrive/CS541/data/wikipedia-list-of-colors.txt").read().splitlines()]

#other colors not mentioned
wiki_colors += ["gold", "golden", "maroon", "orange", 'stone', 'green', 'purple', 'brown', 'multi', 'grey', 'teal_green', 'birch', 'khaki', 'lavender', 'fuschia', 'peacock', 'nutmeg', 'cane', 'oyster', 'spruce']

#appears often and is better used for texture feature
wiki_colors.remove("denim")

# %%
def get_colors(details):
  return [detail for detail in details if detail in wiki_colors]

# %%
for i in range(0, 25):
  print(f"\nSample #{i+1}:")
  print(ecommerce_details[i])
  print("Colors Found:", get_colors(ecommerce_details[i]))

for i in range(29550, 29573):
  print(f"\nSample #{i+1}:")
  print(ecommerce_details[i])
  print("Colors Found:", get_colors(ecommerce_details[i]))
# Out:
# Sample #1:
# ['solid', 'cotton', 'blend', 'collar', 'neck', 'womens', 'a-line', 'dress', 'indigo']
# Colors Found: ['indigo']
#
# Sample #2:
# ['polyester', 'peter', 'pan', 'collar', 'womens', 'blouson', 'dress', 'yellow']
# Colors Found: ['yellow']
#
# Sample #3:
# ['solid', 'polyester', 'blend', 'wide', 'neck', 'womens', 'regular', 'top', 'white']
# Colors Found: ['white']
#
# Sample #4:
# ['stripes', 'polyester', 'sweetheart', 'neck', 'womens', 'dress', 'black']
# Colors Found: ['black']
#
# Sample #5:
# ['regular', 'fit', 'regular', 'length', 'denim', 'womens', 'jeans', 'stone']
# Colors Found: ['stone']
#
# Sample #6:
# ['wide', 'ankle', 'length', 'cotton', 'womens', 'jeans', 'light', 'blue']
# Colors Found: ['blue']
#
# Sample #7:
# ['printed', 'cotton', 'blend', 'collared', 'womens', 'regular', 'dress', 'white']
# Colors Found: ['white']
#
# Sample #8:
# ['embroidered', 'wide', 'neck', 'polyester', 'womens', 'regular', 'top', 'blush']
# Colors Found: ['blush']
#
# Sample #9:
# ['floral', 'polyester', 'v', 'neck', 'womens', 'flared', 'dress', 'navy']
# Colors Found: ['navy']
#
# Sample #10:
# ['checks', 'cotton', 'boat', 'neck', 'womens', 'regular', 'top', 'black']
# Colors Found: ['black']
#
# Sample #11:
# ['solid', 'square', 'neck', 'cotton', 'womens', 'regular', 'dress', 'pink']
# Colors Found: ['pink']
#
# Sample #12:
# ['regular', 'fit', 'regular', 'length', 'denim', 'womens', 'jeans', 'indigo']
# Colors Found: ['indigo']
#
# Sample #13:
# ['printed', 'blended', 'round', 'neck', 'womens', 'shift', 'dress', 'orange']
# Colors Found: ['orange']
#
# Sample #14:
# ['printed', 'jersey', 'round', 'neck', 'womens', 't-shirt', 'black']
# Colors Found: ['black']
#
# Sample #15:
# ['printed', 'crepe', 'square', 'neck', 'womens', 'top', 'blue']
# Colors Found: ['blue']
#
# Sample #16:
# ['solid', 'cotton', 'collar', 'neck', 'womens', 'shirt', 'pink']
# Colors Found: ['pink']
#
# Sample #17:
# ['solid', 'cotton', 'lycra', 'round', 'neck', 'womens', 't-shirt', 'white']
# Colors Found: ['white']
#
# Sample #18:
# ['printed', 'cotton', 'collar', 'neck', 'womens', 'shirt', 'white']
# Colors Found: ['white']
#
# Sample #19:
# ['solid', 'cotton', 'v', 'neck', 'womens', 'formal', 'shirt', 'maroon']
# Colors Found: ['maroon']
#
# Sample #20:
# ['regular', 'fit', 'regular', 'length', 'denim', 'womens', 'jeans', 'mid', 'stone']
# Colors Found: ['stone']
#
# Sample #21:
# ['solid', 'round', 'neck', 'viscose', 'womens', 'regular', 'dress', 'olive']
# Colors Found: ['olive']
#
# Sample #22:
# ['solid', 'wide', 'neck', 'viscose', 'womens', 'regular', 'top', 'blue']
# Colors Found: ['blue']
#
# Sample #23:
# ['printed', 'regular', 'neck', 'cotton', 'womens', 'formal', 'shirt', 'ecru']
# Colors Found: ['ecru']
#
# Sample #24:
# ['regular', 'fit', 'regular', 'length', 'denim', 'womens', 'jeans', 'mid', 'stone']
# Colors Found: ['stone']
#
# Sample #25:
# ['floral', 'viscose', 'sweetheart', 'neck', 'womens', 'dress', 'green']
# Colors Found: ['green']
#
# Sample #29551:
# ['sterling', 'silver', 'gold', 'plated', 'citrine', 'ascending', 'earrings']
# Colors Found: ['silver', 'gold', 'citrine']
#
# Sample #29552:
# ['crystal', 'stylish', 'womens', 'blue', 'necklace']
# Colors Found: ['blue']
#
# Sample #29553:
# ['womens', 'infinity', 'rose', 'gold', 'bracelet', 'using', 'swarovski', 'stones']
# Colors Found: ['rose', 'gold']
#
# Sample #29554:
# ['cotton', 'multicolour', 'girls', 'hair', 'bands']
# Colors Found: []
#
# Sample #29555:
# ['womens', 'modern', 'shapes', 'stone', 'statement', 'necklace', 'multi']
# Colors Found: ['stone', 'multi']
#
# Sample #29556:
# ['elan', 'dual', 'ring', 'rose', 'gold', 'size']
# Colors Found: ['rose', 'gold']
#
# Sample #29557:
# ['combo', 'pack', 'set', 'gold', 'earrings', 'set', 'gold', 'hairpins']
# Colors Found: ['gold', 'gold']
#
# Sample #29558:
# ['silver', 'real', 'pearl', 'aki', 'pendant', 'chain', 'necklace', 'rhodium', 'plated', 'gift']
# Colors Found: ['silver', 'pearl']
#
# Sample #29559:
# ['womens', 'metallic', 'silver', 'double', 'drop', 'black', 'stone', 'western', 'earrings', 'multi']
# Colors Found: ['silver', 'black', 'stone', 'multi']
#
# Sample #29560:
# ['womens', 'sterling', 'silver', 'poppy', 'mangalsutra', 'tanmaniya', 'pendant', 'chain']
# Colors Found: ['silver']
#
# Sample #29561:
# ['vintage', 'motifs', 'multicolor', 'bracelet', 'jf']
# Colors Found: []
#
# Sample #29562:
# ['cubic', 'zirconia', 'silver', 'push', 'back', 'clasp', 'womens', 'earrings']
# Colors Found: ['silver']
#
# Sample #29563:
# ['womens', 'jad', 'pearl', 'golden', 'chain', 'yellow']
# Colors Found: ['pearl', 'golden', 'yellow']
#
# Sample #29564:
# ['womens', 'candy', 'bracelet', 'white', 'american', 'diamonds', 'bracelet']
# Colors Found: ['white']
#
# Sample #29565:
# ['beautiful', 'white', 'crystal', 'silver', 'plated', 'earrings']
# Colors Found: ['white', 'silver']
#
# Sample #29566:
# ['womens', 'metallic', 'gold', 'statement', 'multilayered', 'chain', 'bar', 'ring', 'lock', 'detail', 'western', 'necklace', 'multi']
# Colors Found: ['gold', 'multi']
#
# Sample #29567:
# ['nine', 'pieces', 'combo', 'fashion', 'non-precious', 'metal', 'base', 'earrings']
# Colors Found: []
#
# Sample #29568:
# ['womens', 'pearl', 'golden', 'drops']
# Colors Found: ['pearl', 'golden']
#
# Sample #29569:
# ['sterling', 'silver', 'oval', 'turquoise', 'ear', 'studs']
# Colors Found: ['silver', 'turquoise']
#
# Sample #29570:
# ['constella', 'stylish', 'crystal', 'white', 'pierced', 'earrings']
# Colors Found: ['white']
#
# Sample #29571:
# ['wing', 'woman', 'clover', 'charm', 'necklace']
# Colors Found: []
#
# Sample #29572:
# ['crystal', 'stylish', 'womens', 'rodhium', 'earrings']
# Colors Found: []
#
# Sample #29573:
# ['ethnic', 'gold', 'plated', 'jhumki', 'earrings']
# Colors Found: ['gold']

# %%
color_features = [' '.join(get_colors(detail)) for detail in ecommerce_details]

# %% [markdown]
# ## 3.2) Textures
#
# Create list of textures based off the top-100 words in the ecommerce set

# %%
count_words = sorted(word_dict.items(), key=lambda x: x[1])
top_words = list(reversed(count_words))[25:125]

# %%
plt.figure(figsize=(32,5))
plt.bar([k for (k,v) in top_words], [v for (k,v) in top_words])
plt.title(f"Next Top-100 words in whole ecommerce collection")
plt.xticks(rotation=45)
plt.show()

# %%
texture_names = ["cotton", "solid", "printed", "polyester", "viscose", "silk", "embroidered", "synthetic", "wired", "georgette", "stripes", "linen", "crepe", "structured", "geometric", "denim", "print", "embellished", "poly", "nylon"]

# %%
def get_textures(details):
  return [detail for detail in details if detail in texture_names]

# %%
texture_features = [' '.join(get_textures(detail)) for detail in ecommerce_details]

# %% [markdown]
# ## 3.3) Styles
#
# Create a list of style features

# %%
styles_names = ['regular', 'fit', 'casual', 'blend', 'festive', 'floral', 'straight', 'mandarin', 'ethnic', 'natural', 'palazzo', 'flared', 'night', 'party', 'stylish', 'fancy', 'formal', 'fashion',
                'contemporary', 'simple', 'western', 'vintage', 'every', 'day', 'sports']
def get_styles(details):
  return [detail for detail in details if detail in styles_names]

# %%
style_features = [' '.join(get_styles(detail)) for detail in ecommerce_details]

# %% [markdown]
# ## 3.4) Types
#
# Types of clothes

# %%
types_names = ['neck', 'solid', 'wear', 'kurta', 'top', 'dress', 'set', 'watch', 'saree', 't-shirt', 'bra', 'collar', 'padded', 'v', 'analogue', 'pants', 'sandals', 'shirt', 'jeans', 'slip',
               'earrings', 'v-neck', 'a-line', 'lace', 'strap', 'ankle', 'tunic', 'calf', 'flats', 'shorts', 'sleeves', 'shoes', 'necklace', 'jacket', 'skirt', 'straps', 'trousers', 'blouse',
               'briefs', 'mask', 'bracelet', 'band', 'ring', 'pendant', 'set', 'bangle', 'scarf', 'earring']
def get_types(details):
  return [detail for detail in details if detail in types_names]

# %%
type_features = [' '.join(get_types(detail)) for detail in ecommerce_details]

# %% [markdown]
# ## 3.4) Add New Features

# %%
df['Colors'] = color_features
df['Textures'] = texture_features
df['Styles'] = style_features
df['Types'] = type_features

# %%
df
# Out:
#                 BrandName  \
# 0                    life
# 1                    only
# 2                 fratini
# 3             zink london
# 4                    life
# ...                   ...
# 29570  shaya by caratlane
# 29571           swarovski
# 29572              jewelz
# 29573             estelle
# 29574             estelle
#
#                                                                   Details  \
# 0             solid cotton blend collar neck womens a-line dress - indigo
# 1                polyester peter pan collar womens blouson dress - yellow
# 2          solid polyester blend wide neck womens regular top - off white
# 3                  stripes polyester sweetheart neck womens dress - black
# 4                   regular fit regular length denim womens jeans - stone
# ...                                                                   ...
# 29570                                the wing woman clover charm necklace
# 29571                             crystal stylish womens rodhium earrings
# 29572                                  ethnic gold plated jhumki earrings
# 29573  womens gold plated double line fancy white and gold pearl necklace
# 29574            womens gold plated bridge designer mangalsutra necklaces
#
#                                          Sizes  SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small      849.0  50% off
# 1                             Size:34,36,38,40     2449.0  30% off
# 2                  Size:Large,X-Large,XX-Large      599.0  50% off
# 3              Size:Large,Medium,Small,X-Large     1379.0  40% off
# 4                       Size:26,28,30,32,34,36      849.0  50% off
# ...                                        ...        ...      ...
# 29570                                      NaN     1250.0       No
# 29571                                      NaN     8950.0       No
# 29572                                      NaN      643.0  65% off
# 29573                                      NaN     2799.0       No
# 29574                                      NaN     1899.0       No
#
#                 Category  MinSize  MaxSize  isDiscounted  \
# 0      Westernwear-Women        1        9          True
# 1      Westernwear-Women       11       18          True
# 2      Westernwear-Women        9       15          True
# 3      Westernwear-Women        9       11          True
# 4      Westernwear-Women        2       13          True
# ...                  ...      ...      ...           ...
# 29570    Jewellery-Women       -1       -1         False
# 29571    Jewellery-Women       -1       -1         False
# 29572    Jewellery-Women       -1       -1          True
# 29573    Jewellery-Women       -1       -1         False
# 29574    Jewellery-Women       -1       -1         False
#
#                       Colors           Textures               Styles  \
# 0                     indigo       solid cotton                blend
# 1                     yellow          polyester
# 2                      white    solid polyester        blend regular
# 3                      black  stripes polyester
# 4                      stone              denim  regular fit regular
# ...                      ...                ...                  ...
# 29570
# 29571                                                        stylish
# 29572                   gold                                  ethnic
# 29573  gold white gold pearl                                   fancy
# 29574                   gold
#
#                                 Types
# 0      solid collar neck a-line dress
# 1                        collar dress
# 2                      solid neck top
# 3                          neck dress
# 4                               jeans
# ...                               ...
# 29570                        necklace
# 29571                        earrings
# 29572                        earrings
# 29573                        necklace
# 29574
#
# [29575 rows x 13 columns]

# %% [markdown]
# Check how many rows have empty strings for the new features

# %%
#all features have more than half of rows with some value
print(len(df[df['Colors'] == ""]))
print(len(df[df['Textures'] == ""]))
print(len(df[df['Styles'] == ""]))
print(len(df[df['Types'] == ""]))
# Out:
# 2521
# 8303
# 11158
# 2459

# %% [markdown]
# Only 387~ rows that do not contain any content from new features

# %%
df[(df['Colors'] == "") & (df['Textures'] == "") & (df['Styles'] == "") & (df['Types'] == "")]
# Out:
#        BrandName  \
# 25115       puma
# 25713      timex
# 25926      timex
# 26280   fastrack
# 26318      casio
# ...          ...
# 28864     jewelz
# 29193      shaze
# 29279  belleziya
# 29450  swarovski
# 29496  swarovski
#
#                                                                  Details  \
# 25115  royal challengers bangalore unisex idp flip flops - mixed brights
# 25713                              womens multi-function watch-tw000q806
# 25926                              womens multi-function watch-tw000q810
# 26280                                   fastrack ladies watch-nf6093sl01
# 26318                                round analog wall clock - iq-71-9df
# ...                                                                  ...
# 28864                    bird and sheep shape cute hair clips for babies
# 29193                                           womens tall bridge hoops
# 29279                                       quirky small studs (set of 9
# 29450              time hoop pierced earrings, white, mixed metal finish
# 29496                     tennis deluxe mixed set, white, rhodium plated
#
#           Sizes  SellPrice Discount         Category  MinSize  MaxSize  \
# 25115  Size:6,7      799.0       No   Footwear-Women        6        7
# 25713       NaN     2637.0  40% off    Watches-Women       -1       -1
# 25926       NaN     4395.0       No    Watches-Women       -1       -1
# 26280       NaN     2695.0       No    Watches-Women       -1       -1
# 26318       NaN     1995.0       No    Watches-Women       -1       -1
# ...         ...        ...      ...              ...      ...      ...
# 28864       NaN      318.0  65% off  Jewellery-Women       -1       -1
# 29193       NaN     6700.0       No  Jewellery-Women       -1       -1
# 29279       NaN      799.0       No  Jewellery-Women       -1       -1
# 29450       NaN     6360.0  20% off  Jewellery-Women       -1       -1
# 29496       NaN    14400.0  20% off  Jewellery-Women       -1       -1
#
#        isDiscounted Colors Textures Styles Types
# 25115         False
# 25713          True
# 25926         False
# 26280         False
# 26318         False
# ...             ...    ...      ...    ...   ...
# 28864          True
# 29193         False
# 29279         False
# 29450          True
# 29496          True
#
# [387 rows x 13 columns]

# %% [markdown]
# About 1/3 of the dataset has content from all new features

# %%
df[(df['Colors'] != "") & (df['Textures'] !=  "") & (df['Styles'] !=  "") & (df['Types'] !=  "")]
# Out:
#                 BrandName  \
# 0                    life
# 2                 fratini
# 4                    life
# 6                    life
# 7                 fratini
# ...                   ...
# 25641      lemon & pepper
# 28225                 mia
# 28341              ayesha
# 28889           belleziya
# 29280  shaya by caratlane
#
#                                                                                 Details  \
# 0                           solid cotton blend collar neck womens a-line dress - indigo
# 2                        solid polyester blend wide neck womens regular top - off white
# 4                                 regular fit regular length denim womens jeans - stone
# 6                            printed cotton blend collared womens regular dress - white
# 7                            embroidered wide neck polyester womens regular top - blush
# ...                                                                                 ...
# 25641                 synthetic patent open back womens party wedge heel sandals - gold
# 28225  92.5 silver ring in floral design embellished with multicoloured mother of pearl
# 28341                       womens western metallic silver embellished bracelet - multi
# 28889                                 gold finish and pearl embellished floral necklace
# 29280                            925 oxidised silver floral structured laura d bracelet
#
#                                          Sizes  SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small      849.0  50% off
# 2                  Size:Large,X-Large,XX-Large      599.0  50% off
# 4                       Size:26,28,30,32,34,36      849.0  50% off
# 6      Size:Large,Medium,Small,X-Large,X-Small      649.0  50% off
# 7                                Size:XX-Large      649.0  50% off
# ...                                        ...        ...      ...
# 25641                      Size:36,37,38,39,40     1959.0  30% off
# 28225                                      NaN     5500.0       No
# 28341                                      NaN      149.0  70% off
# 28889                                      NaN      799.0       No
# 29280                                      NaN     5760.0  10% off
#
#                 Category  MinSize  MaxSize  isDiscounted        Colors  \
# 0      Westernwear-Women        1        9          True        indigo
# 2      Westernwear-Women        9       15          True         white
# 4      Westernwear-Women        2       13          True         stone
# 6      Westernwear-Women        1        9          True         white
# 7      Westernwear-Women       15       15          True         blush
# ...                  ...      ...      ...           ...           ...
# 25641     Footwear-Women       13       18          True          gold
# 28225    Jewellery-Women       -1       -1         False  silver pearl
# 28341    Jewellery-Women       -1       -1          True  silver multi
# 28889    Jewellery-Women       -1       -1         False    gold pearl
# 29280    Jewellery-Women       -1       -1          True        silver
#
#                     Textures               Styles  \
# 0               solid cotton                blend
# 2            solid polyester        blend regular
# 4                      denim  regular fit regular
# 6             printed cotton        blend regular
# 7      embroidered polyester              regular
# ...                      ...                  ...
# 25641              synthetic                party
# 28225            embellished               floral
# 28341            embellished              western
# 28889            embellished               floral
# 29280             structured               floral
#
#                                 Types
# 0      solid collar neck a-line dress
# 2                      solid neck top
# 4                               jeans
# 6                               dress
# 7                            neck top
# ...                               ...
# 25641                         sandals
# 28225                            ring
# 28341                        bracelet
# 28889                        necklace
# 29280                        bracelet
#
# [13179 rows x 13 columns]

# %% [markdown]
# # 3) Models

# %%
df
# Out:
#                 BrandName  \
# 0                    life
# 1                    only
# 2                 fratini
# 3             zink london
# 4                    life
# ...                   ...
# 29570  shaya by caratlane
# 29571           swarovski
# 29572              jewelz
# 29573             estelle
# 29574             estelle
#
#                                                                   Details  \
# 0             solid cotton blend collar neck womens a-line dress - indigo
# 1                polyester peter pan collar womens blouson dress - yellow
# 2          solid polyester blend wide neck womens regular top - off white
# 3                  stripes polyester sweetheart neck womens dress - black
# 4                   regular fit regular length denim womens jeans - stone
# ...                                                                   ...
# 29570                                the wing woman clover charm necklace
# 29571                             crystal stylish womens rodhium earrings
# 29572                                  ethnic gold plated jhumki earrings
# 29573  womens gold plated double line fancy white and gold pearl necklace
# 29574            womens gold plated bridge designer mangalsutra necklaces
#
#                                          Sizes  SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small      849.0  50% off
# 1                             Size:34,36,38,40     2449.0  30% off
# 2                  Size:Large,X-Large,XX-Large      599.0  50% off
# 3              Size:Large,Medium,Small,X-Large     1379.0  40% off
# 4                       Size:26,28,30,32,34,36      849.0  50% off
# ...                                        ...        ...      ...
# 29570                                      NaN     1250.0       No
# 29571                                      NaN     8950.0       No
# 29572                                      NaN      643.0  65% off
# 29573                                      NaN     2799.0       No
# 29574                                      NaN     1899.0       No
#
#                 Category  MinSize  MaxSize  isDiscounted  \
# 0      Westernwear-Women        1        9          True
# 1      Westernwear-Women       11       18          True
# 2      Westernwear-Women        9       15          True
# 3      Westernwear-Women        9       11          True
# 4      Westernwear-Women        2       13          True
# ...                  ...      ...      ...           ...
# 29570    Jewellery-Women       -1       -1         False
# 29571    Jewellery-Women       -1       -1         False
# 29572    Jewellery-Women       -1       -1          True
# 29573    Jewellery-Women       -1       -1         False
# 29574    Jewellery-Women       -1       -1         False
#
#                       Colors           Textures               Styles  \
# 0                     indigo       solid cotton                blend
# 1                     yellow          polyester
# 2                      white    solid polyester        blend regular
# 3                      black  stripes polyester
# 4                      stone              denim  regular fit regular
# ...                      ...                ...                  ...
# 29570
# 29571                                                        stylish
# 29572                   gold                                  ethnic
# 29573  gold white gold pearl                                   fancy
# 29574                   gold
#
#                                 Types
# 0      solid collar neck a-line dress
# 1                        collar dress
# 2                      solid neck top
# 3                          neck dress
# 4                               jeans
# ...                               ...
# 29570                        necklace
# 29571                        earrings
# 29572                        earrings
# 29573                        necklace
# 29574
#
# [29575 rows x 13 columns]

# %% [markdown]
# ## 3.1) Keyword Extractor

# %%
# !pip install keybert
from keybert import KeyBERT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keybert in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.10/dist-packages (from keybert) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.22.4)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.14.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.28.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.15.1+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.14.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (16.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)

# %%
class BertKWExtractor:

  def __init__(self, feature_dictionary, top_n=5, drop_rate=0.2):
    self.bert_model = KeyBERT(model='all-mpnet-base-v2')
    self.top_n = top_n
    self.drop_rate = drop_rate
    self.feature_dictionary = feature_dictionary

  def filter_keywords(self, keyword_list):
    return [k for k in keyword_list if k in self.feature_dictionary]

  def __call__(self, text):
    text = text.lower()
    results = self.bert_model.extract_keywords(text,
                                     keyphrase_ngram_range=(1, 1),
                                     stop_words='english',
                                     highlight=False,
                                     top_n=self.top_n)
    return [k for (k, v) in results if v >= self.drop_rate]

# %%
feature_dict = types_names + styles_names + texture_names + wiki_colors + ["discounted", "discount", "small", "medium", "large"] + df['BrandName'].unique().tolist()

bert_model = BertKWExtractor(feature_dict, top_n=10)

# %%
text = "I am looking red puma shoes that are on discount. I need something that is festive. I like pineapples."

results = bert_model(text)
print(results)
print(f"Final keywords: {bert_model.filter_keywords(results)}")
# Out:
# ['puma', 'shoes', 'pineapples', 'discount', 'red', 'festive']
# Final keywords: ['puma', 'shoes', 'discount', 'red', 'festive']

# %% [markdown]
# Using KeyBert we can extract feature names from a sentence, drop low quality words, and filter based on predefined list of existing features in dataset.

# %% [markdown]
# ## 3.2) Market Basket Analysis

# %%
columns_to_extract = ['Colors', 'Textures', 'Styles', 'Types']

# Extract specific columns and put them into a list of lists
dfx=df[(df['Colors'] != "") & (df['Textures'] !=  "") & (df['Styles'] !=  "") & (df['Types'] !=  "")]
extracted_data = dfx.dropna(subset=columns_to_extract)[columns_to_extract].values.tolist()

print(extracted_data)
# Out:
# [['indigo', 'solid cotton', 'blend', 'solid collar neck a-line dress'], ['white', 'solid polyester', 'blend regular', 'solid neck top'], ['stone', 'denim', 'regular fit regular', 'jeans'], ['white', 'printed cotton', 'blend regular', 'dress'], ['blush', 'embroidered polyester', 'regular', 'neck top'], ['navy', 'polyester', 'floral flared', 'v neck dress'], ['black', 'cotton', 'regular', 'neck top'], ['pink', 'solid cotton', 'regular', 'solid neck dress'], ['indigo', 'denim', 'regular fit regular', 'jeans'], ['maroon', 'solid cotton', 'formal', 'solid v neck shirt'], ['stone', 'denim', 'regular fit regular', 'jeans'], ['olive', 'solid viscose', 'regular', 'solid neck dress'], ['blue', 'solid viscose', 'regular', 'solid neck top'], ['ecru', 'printed cotton', 'regular formal', 'neck shirt'], ['stone', 'denim', 'regular fit regular', 'jeans'], ['green', 'viscose', 'floral', 'neck dress'], ['white', 'printed viscose', 'regular', 'v neck top'], ['pink', 'printed cotton', 'blend', 'v neck top'], ['maroon', 'solid cotton', 'blend', 'solid v neck top'], ['black', 'printed cotton', 'regular formal', 'neck shirt'], ['white', 'printed cotton', 'blend', 'neck t-shirt'], ['white', 'embroidered viscose', 'regular', 'neck top'], ['indigo', 'denim', 'regular fit regular', 'jeans'], ['brown', 'solid cotton', 'regular', 'solid neck dress'], ['white', 'printed polyester', 'blend', 'neck a-line dress'], ['black', 'solid', 'regular fit', 'solid trousers'], ['pink', 'cotton', 'regular fit regular', 'set'], ['sage', 'solid viscose', 'regular', 'solid neck top'], ['navy', 'printed polyester', 'regular', 'collar neck top'], ['mustard', 'solid viscose', 'regular', 'solid v-neck top'], ['black', 'polyester', 'floral flared', 'dress'], ['pink', 'printed viscose', 'regular', 'neck dress'], ['grey', 'printed cotton', 'fit blend', 'wear pants'], ['blue', 'printed cotton denim', 'regular formal', 'neck shirt'], ['olive', 'denim', 'regular fit regular', 'jeans'], ['red', 'printed cotton', 'blend', 'collar neck t-shirt'], ['green', 'printed polyester', 'blend', 'neck dress'], ['blue', 'polyester', 'floral flared', 'v neck dress'], ['black', 'solid viscose', 'regular', 'solid neck dress'], ['black', 'solid polyester', 'fit casual', 'solid wear trousers'], ['pink', 'polyester', 'regular fit casual', 'trousers'], ['pink', 'viscose', 'regular', 'neck'], ['green', 'solid cotton', 'formal', 'solid v neck shirt'], ['pink', 'solid cotton', 'blend', 'solid neck t-shirt'], ['pink', 'printed georgette', 'regular', 'neck dress'], ['indigo', 'cotton', 'fit regular', 'jeans'], ['white', 'printed viscose', 'regular', 'neck top'], ['white', 'cotton', 'regular fit regular', 'jeans'], ['tan', 'solid viscose', 'regular', 'solid neck dress'], ['blue', 'cotton', 'fit blend', 'ankle jeans'], ['sage', 'cotton', 'blend regular', 'collar neck top'], ['blue', 'embroidered cotton', 'blend', 'neck top'], ['black', 'solid polyester', 'blend flared', 'solid neck dress'], ['sage', 'solid polyester', 'flared', 'solid neck dress'], ['blue', 'cotton', 'fit', 'ankle jeans'], ['stone', 'cotton', 'regular fit regular', 'jeans'], ['grey', 'printed polyester', 'fit', 'dress'], ['sage', 'solid polyester', 'regular', 'solid neck top'], ['white', 'cotton', 'regular fit regular blend', 'jeans'], ['pink', 'printed polyester', 'regular', 'neck dress'], ['green', 'solid polyester', 'casual', 'solid collar neck shirt'], ['white', 'embroidered cotton', 'regular', 'neck dress'], ['black', 'printed cotton', 'blend', 'neck t-shirt'], ['blue', 'cotton', 'fit', 'ankle jeans'], ['pink', 'solid polyester', 'blend', 'solid neck a-line dress'], ['blue', 'cotton', 'fit blend', 'ankle jeans'], ['navy', 'cotton', 'fit blend', 'jeans'], ['white', 'printed cotton', 'regular formal', 'neck shirt'], ['pink', 'denim', 'regular fit regular', 'jeans'], ['black', 'cotton', 'fit regular', 'jeans'], ['blue', 'solid cotton', 'regular blend formal', 'solid neck shirt'], ['lilac', 'solid polyester', 'blend', 'solid ankle'], ['black' ...

# %%
# !pip install mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: scipy>=0.17 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.22.4)
# Requirement already satisfied: pandas>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mlxtend) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->mlxtend) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->mlxtend) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->mlxtend) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.17.1->mlxtend) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->mlxtend) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.5.1->mlxtend) (1.16.0)

# %%
te = TransactionEncoder()
te_array = te.fit_transform(extracted_data)
df1 = pd.DataFrame(te_array, columns=te.columns_)

# %%
df1
# Out:
#        a-line dress  a-line kurta  a-line skirt  a-line solid wear trousers  \
# 0             False         False         False                       False
# 1             False         False         False                       False
# 2             False         False         False                       False
# 3             False         False         False                       False
# 4             False         False         False                       False
# ...             ...           ...           ...                         ...
# 13174         False         False         False                       False
# 13175         False         False         False                       False
# 13176         False         False         False                       False
# 13177         False         False         False                       False
# 13178         False         False         False                       False
#
#        a-line top  a-line wear  a-line wear kurta  ankle  ankle jeans  \
# 0           False        False              False  False        False
# 1           False        False              False  False        False
# 2           False        False              False  False        False
# 3           False        False              False  False        False
# 4           False        False              False  False        False
# ...           ...          ...                ...    ...          ...
# 13174       False        False              False  False        False
# 13175       False        False              False  False        False
# 13176       False        False              False  False        False
# 13177       False        False              False  False        False
# 13178       False        False              False  False        False
#
#        ankle kurta  ...   wine  wine gold magenta  \
# 0            False  ...  False              False
# 1            False  ...  False              False
# 2            False  ...  False              False
# 3            False  ...  False              False
# 4            False  ...  False              False
# ...            ...  ...    ...                ...
# 13174        False  ...  False              False
# 13175        False  ...  False              False
# 13176        False  ...  False              False
# 13177        False  ...  False              False
# 13178        False  ...  False              False
#
#        wine gold wine gold magenta  wine golden magenta  wine purple  wired  \
# 0                            False                False        False  False
# 1                            False                False        False  False
# 2                            False                False        False  False
# 3                            False                False        False  False
# 4                            False                False        False  False
# ...                            ...                  ...          ...    ...
# 13174                        False                False        False  False
# 13175                        False                False        False  False
# 13176                        False                False        False  False
# 13177                        False                False        False  False
# 13178                        False                False        False  False
#
#        wired denim  yellow  yellow blue  yellow yellow
# 0            False   False        False          False
# 1            False   False        False          False
# 2            False   False        False          False
# 3            False   False        False          False
# 4            False   False        False          False
# ...            ...     ...          ...            ...
# 13174        False   False        False          False
# 13175        False   False        False          False
# 13176        False   False        False          False
# 13177        False   False        False          False
# 13178        False   False        False          False
#
# [13179 rows x 1071 columns]

# %%
min_support = 0.1
frequent_itemsets = apriori(df1, min_support=min_support, use_colnames=True)

# %%
frequent_itemsets
# Out:
#     support   itemsets
# 0  0.116549    (black)
# 1  0.118142     (blue)
# 2  0.117308   (cotton)
# 3  0.111617  (regular)

# %%
min_confidence = 0.0000001
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=min_confidence)

# %%
rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# ## 3.3) Chat bot using keybert and Jaccard similarity [Content based filtering]

# %%
def jaccard_similarity(list1, list2):
    set1 = set(list1)
    set2 = set(list2)
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union

# %%
def rank_top_n(reference_list, lists_of_lists,n=5):
    similarities = []
    for idx, lst in enumerate(lists_of_lists):
        similarity = jaccard_similarity(reference_list, lst)
        similarities.append((idx, similarity))
    similarities.sort(key=lambda x: x[1], reverse=True)
    return [idx for idx, similarity in similarities[:n]]

# %%
while True:
    user_input = input("Please enter something: ")
    if(user_input=='\quit'):
      break
    else:
      results = bert_model(user_input)
      print(results)
      rank=rank_top_n(results, extracted_data,5)
      print("Top 5 most similar products:", rank)
      for i in rank:
        print(dfx.iloc[i])
# Out:
# Please enter something: I am looking for white shirt and navy blue pants.
# ['shirt', 'pants', 'navy', 'white', 'blue', 'looking']
# Top 5 most similar products: [392, 455, 941, 949, 1006]
# BrandName                                              van heusen
# Details         stripes regular fit polyester womens pants - navy
# Sizes                                               Size:26,30,32
# SellPrice                                                   999.0
# Discount                                                  57% off
# Category                                        Westernwear-Women
# MinSize                                                         2
# MaxSize                                                         9
# isDiscounted                                                 True
# Colors                                                       navy
# Textures                                        stripes polyester
# Styles                                                regular fit
# Types                                                       pants
# Name: 629, dtype: object
# BrandName                                                        van heusen
# Details         checks regular fit polyester womens formal pants - mid blue
# Sizes                                                   Size:26,28,30,32,34
# SellPrice                                                            1499.0
# Discount                                                            25% off
# Category                                                  Westernwear-Women
# MinSize                                                                   2
# MaxSize                                                                  11
# isDiscounted                                                           True
# Colors                                                                 blue
# Textures                                                          polyester
# Styles                                                   regular fit formal
# Types                                                                 pants
# Name: 731, dtype: object
# BrandName                                                 and
# Details         flared fit cotton womens casual pants - white
# Sizes                                  Size:26,28,30,32,34,36
# SellPrice                                              2799.0
# Discount                                                   No
# Category                                    Westernwear-Women
# MinSize                                                     2
# MaxSize                                                    13
# isDiscounted                                            False
# Colors                                                  white
# Textures                                               cotton
# Styles                                      flared fit casual
# Types                                                   pants
# Name: 1530, dtype: object
# BrandName                                                       van heusen
# Details         textured regular fit polyester viscose womens pants - navy
# Sizes                                                     Size:28,30,32,34
# SellPrice                                                            999.0
# Discount                                                           60% off
# Category                                                 Westernwear-Women
# MinSize                                                                  4
# MaxSize                                                                 11
# isDiscounted                                                          True
# Colors                                                                navy
# Textures                                                 polyester viscose
# Styles                                                         regular fit
# Types                                                                pants
# Name: 1544, dtype: object
# BrandName                                                        van heusen
# Details         checks regular fit polyester womens formal pants - mid blue
# Sizes                                                   Size:26,28,30,32,34
# SellPrice                                                            1999.0
# Discount                                                                 No
# Category                                                  Westernwear-Women
# MinSize                                                                   2
# MaxSize                                                                  11
# isDiscounted                                                          False
# Colors                                                                 blue
# Textures                                                          polyester
# Styles                                                   regular fit formal
# Types                                                                 pants
# Name: 1643, dtype: object
# Please enter something: \quit

# %%
dfx.iloc[12664]
# Out:
# BrandName                                                       puma
# Details         synthetic low boot laces unisex sports shoes - black
# Sizes                                                         Size:7
# SellPrice                                                     5999.0
# Discount                                                          No
# Category                                              Footwear-Women
# MinSize                                                            7
# MaxSize                                                            7
# isDiscounted                                                   False
# Colors                                                         black
# Textures                                                   synthetic
# Styles                                                        sports
# Types                                                          shoes
# Name: 23360, dtype: object
